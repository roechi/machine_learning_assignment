# %%
import pandas as pd

# %%
df = pd.read_csv('./data/cs-train_cropped.csv')
df.shape
# Out:
# (119840, 12)

# %%
df = df.dropna()
df.shape
# Out:
# (119840, 12)

# %%
df = df.drop('Unnamed: 0', axis=1)
df
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                      1                              0.766127   45
# 1                      0                              0.957151   40
# 2                      0                              0.658180   38
# 3                      0                              0.233810   30
# 4                      0                              0.907239   49
# 5                      0                              0.213179   74
# 6                      0                              0.754464   39
# 7                      0                              0.189169   57
# 8                      0                              0.644226   30
# 9                      0                              0.018798   51
# 10                     0                              0.010352   46
# 11                     1                              0.964673   40
# 12                     0                              0.019657   76
# ...

# %%
df.to_csv('./data/cs-train_cropped.csv')
